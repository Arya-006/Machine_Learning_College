# %% [markdown]
# <a href="https://colab.research.google.com/github/Arya-006/Machine_Learning_College/blob/main/Practical_No_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name: ")
print("Hello,", name, "! Welcome!")
# Out:
# Enter your name: Arya
# Hello, Arya ! Welcome!

# %%
#Example for identation error
if 6 > 3:
print("Six is greater than three")
# Out:
#   File "/tmp/ipykernel_2343/3740717655.py", line 3
#     print("Six is greater than three")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
if 6 > 5:
  print("Six is greater than three")

# %%
# Example for exceptional handling
my_var = 40
_var = 50
var2 = 60
print(my_var)
print(_var)
print(var2)

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("You are eligible to drive.")
else:
    print("You are not eligible to drive.")

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print(num, "is an even number.")
else:
    print(num, "is an odd number.")

# %%
#print which one larger or if they are equal.

num
